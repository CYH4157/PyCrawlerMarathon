# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"17354829524","type":"WatchEvent","actor":{"id":30111952,"login":"i-aditya-kaushik","display_login":"i-aditya-kaushik","gravatar_id":"","url":"https://api.github.com/users/i-aditya-kaushik","avatar_url":"https://avatars.githubusercontent.com/u/30111952?"},"repo":{"id":305570951,"name":"bezkoder/react-material-ui-examples","url":"https://api.github.com/repos/bezkoder/react-material-ui-examples"},"payload":{"action":"started"},"public":true,"created_at":"2021-07-29T13:18:05Z"},{"id":"17354829502","type":"ForkEvent","actor":{"id":86573128,"login":"instrui","display_login":"instrui","gravatar_id":"","url":"https://api.github.com/users/instrui","avatar_url":"https://avatars.githubusercontent.com/u/86573128?"},"repo":{"id":254721335,"name":"minecraft-linux/CX","url":"https://api.github.com/repos/minecraft-linux/CX"},"payload":{"forkee":{"id":390730218,"node_id":"MDEwOlJlcG9zaXRvcnkzOTA3MzAyMTg=","name":"CX","full_name":"instrui/CX","private":false,"owner":{"login":"instrui","id":86573128,"node_id":"MDQ6VXNlcjg2NTczMTI4","avatar_url":"https://avatars.githubusercontent.com/u/86573128?v=4","gravatar_id":"","url":"https://api.github.com/users/instrui","html_url":"https://github.com/instrui","followers_url":"https://api.github.com/users/instrui/followers","following_url":"https://api.github.com/users/instrui/following{/other_user}","gists_url":"https://api.github.com/users/instrui/gists{/gist_id}","starred_url":"https://api.github.com/users/instrui/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/instrui/subscriptions","organizations_url":"https://api.github.com/users/instrui/orgs","repos_url":"https://api.github.com/users/instrui/repos","events_url":"https://api.github.com/users/instrui/events{/privacy}","received_events_url":"https://api.github.com/users/instrui/received_events","type":"User","site_admin":false},"html_url":"https://github.com/instrui/CX","description":"A collection of conxtexpr tools for diverting non-operating boilerplate abstractions to compile-time.","fork":true,"url":"https://api.github.com/repos/instrui/CX","forks_url":"https://api.github.com/repos/instrui/CX/forks","keys_url":"https://api.github.com/repos/instrui/CX/keys{/key_id}","collaborators_url":"https://api.github.com/repos/instrui/CX/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/instrui/CX/teams","hooks_url":"https://api.github.com/repos/instrui/CX/hooks","issue_events_url":"https://api.github.com/repos/instrui/CX/issues/events{/number}","events_url":"https://api.github.com/repos/instrui/CX/events","assignees_url":"https://api.github.com/repos/instrui/CX/assignees{/user}","branches_url":"https://api.github.com/repos/instrui/CX/branches{/branch}","tags_url":"https://api.github.com/repos/instrui/CX/tags","blobs_url":"https://api.github.com/repos/instrui/CX/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/instrui/CX/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/instrui/CX/git/refs{/sha}","trees_url":"https://api.github.com/repos/instrui/CX/git/trees{/sha}","statuses_url":"https://api.github.com/repos/instrui/CX/statuses/{sha}","languages_url":"https://api.github.com/repos/instrui/CX/languages","stargazers_url":"https://api.github.com/repos/instrui/CX/stargazers","contributors_url":"https://api.github.com/repos/instrui/CX/contributors","subscribers_url":"https://api.github.com/repos/instrui/CX/subscribers","subscription_url":"https://api.github.com/repos/instrui/CX/subscription","commits_url":"https://api.github.com/repos/instrui/CX/commits{/sha}","git_commits_url":"https://api.github.com/repos/instrui/CX/git/commits{/sha}","comments_url":"https://api.github.com/repos/instrui/CX/comments{/number}","issue_comment_url":"https://api.github.com/repos/instrui/CX/issues/comments{/number}","contents_url":"https://api.github.com/repos/instrui/CX/contents/{+path}","compare_url":"https://api.github.com/repos/instrui/CX/compare/{base}...{head}","merges_url":"https://api.github.com/repo ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '17354829524',
#   'type': 'WatchEvent',
#   'actor': {'id': 30111952,
#    'login': 'i-aditya-kaushik',
#    'display_login': 'i-aditya-kaushik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/i-aditya-kaushik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30111952?'},
#   'repo': {'id': 305570951,
#    'name': 'bezkoder/react-material-ui-examples',
#    'url': 'https://api.github.com/repos/bezkoder/react-material-ui-examples'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829502',
#   'type': 'ForkEvent',
#   'actor': {'id': 86573128,
#    'login': 'instrui',
#    'display_login': 'instrui',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/instrui',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/86573128?'},
#   'repo': {'id': 254721335,
#    'name': 'minecraft-linux/CX',
#    'url': 'https://api.github.com/repos/minecraft-linux/CX'},
#   'payload': {'forkee': {'id': 390730218,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzOTA3MzAyMTg=',
#     'name': 'CX',
#     'full_name': 'instrui/CX',
#     'private': False,
#     'owner': {'login': 'instrui',
#      'id': 86573128,
#      'node_id': 'MDQ6VXNlcjg2NTczMTI4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/86573128?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/instrui',
#      'html_url': 'https://github.com/instrui',
#      'followers_url': 'https://api.github.com/users/instrui/followers',
#      'following_url': 'https://api.github.com/users/instrui/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/instrui/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/instrui/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/instrui/subscriptions',
#      'organizations_url': 'https://api.github.com/users/instrui/orgs',
#      'repos_url': 'https://api.github.com/users/instrui/repos',
#      'events_url': 'https://api.github.com/users/instrui/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/instrui/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/instrui/CX',
#     'description': 'A collection of conxtexpr tools for diverting non-operating boilerplate abstractions to compile-time.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/instrui/CX',
#     'forks_url': 'https://api.github.com/repos/instrui/CX/forks',
#     'keys_url': 'https://api.github.com/repos/instrui/CX/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/instrui/CX/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/instrui/CX/teams',
#     'hooks_url': 'https://api.github.com/repos/instrui/CX/hooks',
#     'issue_events_url': 'https://api.github.com/repos/instrui/CX/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/instrui/CX/events',
#     'assignees_url': 'https://api.github.com/repos/instrui/CX/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/instrui/CX/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/instrui/CX/tags',
#     'blobs_url': 'https://api.github.com/repos/instrui/CX/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/instrui/CX/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/instrui/CX/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/instrui/CX/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/instrui/CX/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/instrui/CX/languages',
#     'stargazers_url': 'https://api.github.com/repos/instrui/CX/stargazers',
#     'contributors_url': 'https://api.github.com/repos/instrui/CX/contributors',
#     'subscribers_url': 'https://api.github.com/repos/instrui/CX/subscribers',
#     'subscription_url': 'https://api.github.com/repos/instrui/CX/subscription',
#     'commits_url': 'https://api.github.com/repos/instrui/CX/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/instrui/CX/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/instrui/CX/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/instrui/CX/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/instrui/CX/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/instrui/CX/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/instrui/CX/merges',
#     'archive_url': 'https://api.github.com/repos/instrui/CX/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/instrui/CX/downloads',
#     'issues_url': 'https://api.github.com/repos/instrui/CX/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/instrui/CX/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/instrui/CX/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/instrui/CX/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/instrui/CX/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/instrui/CX/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/instrui/CX/deployments',
#     'created_at': '2021-07-29T13:18:05Z',
#     'updated_at': '2020-04-21T21:54:10Z',
#     'pushed_at': '2020-04-21T21:54:08Z',
#     'git_url': 'git://github.com/instrui/CX.git',
#     'ssh_url': 'git@github.com:instrui/CX.git',
#     'clone_url': 'https://github.com/instrui/CX.git',
#     'svn_url': 'https://github.com/instrui/CX',
#     'homepage': '',
#     'size': 70,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z',
#   'org': {'id': 37957378,
#    'login': 'minecraft-linux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/minecraft-linux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37957378?'}},
#  {'id': '17354829514',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 71653044,
#    'login': 'hzheng-ledger',
#    'display_login': 'hzheng-ledger',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hzheng-ledger',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71653044?'},
#   'repo': {'id': 382023847,
#    'name': 'LedgerHQ/wallet-btc',
#    'url': 'https://api.github.com/repos/LedgerHQ/wallet-btc'},
#   'payload': {'action': 'opened',
#    'number': 27,
#    'pull_request': {'url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/27',
#     'id': 699526150,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0Njk5NTI2MTUw',
#     'html_url': 'https://github.com/LedgerHQ/wallet-btc/pull/27',
#     'diff_url': 'https://github.com/LedgerHQ/wallet-btc/pull/27.diff',
#     'patch_url': 'https://github.com/LedgerHQ/wallet-btc/pull/27.patch',
#     'issue_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/27',
#     'number': 27,
#     'state': 'open',
#     'locked': False,
#     'title': 'Increase batch size',
#     'user': {'login': 'hzheng-ledger',
#      'id': 71653044,
#      'node_id': 'MDQ6VXNlcjcxNjUzMDQ0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/71653044?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hzheng-ledger',
#      'html_url': 'https://github.com/hzheng-ledger',
#      'followers_url': 'https://api.github.com/users/hzheng-ledger/followers',
#      'following_url': 'https://api.github.com/users/hzheng-ledger/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hzheng-ledger/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hzheng-ledger/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hzheng-ledger/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hzheng-ledger/orgs',
#      'repos_url': 'https://api.github.com/users/hzheng-ledger/repos',
#      'events_url': 'https://api.github.com/users/hzheng-ledger/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hzheng-ledger/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'I change the batch size so that the sync is faster for big accounts',
#     'created_at': '2021-07-29T13:18:05Z',
#     'updated_at': '2021-07-29T13:18:05Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/27/commits',
#     'review_comments_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/27/comments',
#     'review_comment_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/27/comments',
#     'statuses_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/statuses/03d8441ad751a2e550c89147395caf0927483fe1',
#     'head': {'label': 'LedgerHQ:change_batchsize',
#      'ref': 'change_batchsize',
#      'sha': '03d8441ad751a2e550c89147395caf0927483fe1',
#      'user': {'login': 'LedgerHQ',
#       'id': 9784193,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk3ODQxOTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9784193?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/LedgerHQ',
#       'html_url': 'https://github.com/LedgerHQ',
#       'followers_url': 'https://api.github.com/users/LedgerHQ/followers',
#       'following_url': 'https://api.github.com/users/LedgerHQ/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/LedgerHQ/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/LedgerHQ/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/LedgerHQ/subscriptions',
#       'organizations_url': 'https://api.github.com/users/LedgerHQ/orgs',
#       'repos_url': 'https://api.github.com/users/LedgerHQ/repos',
#       'events_url': 'https://api.github.com/users/LedgerHQ/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/LedgerHQ/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 382023847,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzODIwMjM4NDc=',
#       'name': 'wallet-btc',
#       'full_name': 'LedgerHQ/wallet-btc',
#       'private': False,
#       'owner': {'login': 'LedgerHQ',
#        'id': 9784193,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk3ODQxOTM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9784193?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/LedgerHQ',
#        'html_url': 'https://github.com/LedgerHQ',
#        'followers_url': 'https://api.github.com/users/LedgerHQ/followers',
#        'following_url': 'https://api.github.com/users/LedgerHQ/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/LedgerHQ/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/LedgerHQ/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/LedgerHQ/subscriptions',
#        'organizations_url': 'https://api.github.com/users/LedgerHQ/orgs',
#        'repos_url': 'https://api.github.com/users/LedgerHQ/repos',
#        'events_url': 'https://api.github.com/users/LedgerHQ/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/LedgerHQ/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/LedgerHQ/wallet-btc',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/LedgerHQ/wallet-btc',
#       'forks_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/forks',
#       'keys_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/teams',
#       'hooks_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/hooks',
#       'issue_events_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/events',
#       'assignees_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/tags',
#       'blobs_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/languages',
#       'stargazers_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/stargazers',
#       'contributors_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/contributors',
#       'subscribers_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/subscribers',
#       'subscription_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/subscription',
#       'commits_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/merges',
#       'archive_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/downloads',
#       'issues_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/deployments',
#       'created_at': '2021-07-01T12:22:01Z',
#       'updated_at': '2021-07-29T06:30:26Z',
#       'pushed_at': '2021-07-29T13:18:05Z',
#       'git_url': 'git://github.com/LedgerHQ/wallet-btc.git',
#       'ssh_url': 'git@github.com:LedgerHQ/wallet-btc.git',
#       'clone_url': 'https://github.com/LedgerHQ/wallet-btc.git',
#       'svn_url': 'https://github.com/LedgerHQ/wallet-btc',
#       'homepage': None,
#       'size': 25515,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'LedgerHQ:master',
#      'ref': 'master',
#      'sha': '1cb677f0ac11a46a6cdf1d1b99c0f3d22972fd09',
#      'user': {'login': 'LedgerHQ',
#       'id': 9784193,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk3ODQxOTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/9784193?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/LedgerHQ',
#       'html_url': 'https://github.com/LedgerHQ',
#       'followers_url': 'https://api.github.com/users/LedgerHQ/followers',
#       'following_url': 'https://api.github.com/users/LedgerHQ/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/LedgerHQ/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/LedgerHQ/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/LedgerHQ/subscriptions',
#       'organizations_url': 'https://api.github.com/users/LedgerHQ/orgs',
#       'repos_url': 'https://api.github.com/users/LedgerHQ/repos',
#       'events_url': 'https://api.github.com/users/LedgerHQ/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/LedgerHQ/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 382023847,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzODIwMjM4NDc=',
#       'name': 'wallet-btc',
#       'full_name': 'LedgerHQ/wallet-btc',
#       'private': False,
#       'owner': {'login': 'LedgerHQ',
#        'id': 9784193,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjk3ODQxOTM=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/9784193?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/LedgerHQ',
#        'html_url': 'https://github.com/LedgerHQ',
#        'followers_url': 'https://api.github.com/users/LedgerHQ/followers',
#        'following_url': 'https://api.github.com/users/LedgerHQ/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/LedgerHQ/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/LedgerHQ/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/LedgerHQ/subscriptions',
#        'organizations_url': 'https://api.github.com/users/LedgerHQ/orgs',
#        'repos_url': 'https://api.github.com/users/LedgerHQ/repos',
#        'events_url': 'https://api.github.com/users/LedgerHQ/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/LedgerHQ/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/LedgerHQ/wallet-btc',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/LedgerHQ/wallet-btc',
#       'forks_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/forks',
#       'keys_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/teams',
#       'hooks_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/hooks',
#       'issue_events_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/events',
#       'assignees_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/tags',
#       'blobs_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/languages',
#       'stargazers_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/stargazers',
#       'contributors_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/contributors',
#       'subscribers_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/subscribers',
#       'subscription_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/subscription',
#       'commits_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/merges',
#       'archive_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/downloads',
#       'issues_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/LedgerHQ/wallet-btc/deployments',
#       'created_at': '2021-07-01T12:22:01Z',
#       'updated_at': '2021-07-29T06:30:26Z',
#       'pushed_at': '2021-07-29T13:18:05Z',
#       'git_url': 'git://github.com/LedgerHQ/wallet-btc.git',
#       'ssh_url': 'git@github.com:LedgerHQ/wallet-btc.git',
#       'clone_url': 'https://github.com/LedgerHQ/wallet-btc.git',
#       'svn_url': 'https://github.com/LedgerHQ/wallet-btc',
#       'homepage': None,
#       'size': 25515,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 1,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/27'},
#      'html': {'href': 'https://github.com/LedgerHQ/wallet-btc/pull/27'},
#      'issue': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/27'},
#      'comments': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/issues/27/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/27/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/pulls/27/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/LedgerHQ/wallet-btc/statuses/03d8441ad751a2e550c89147395caf0927483fe1'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 3,
#     'deletions': 3,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z',
#   'org': {'id': 9784193,
#    'login': 'LedgerHQ',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/LedgerHQ',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9784193?'}},
#  {'id': '17354829528',
#   'type': 'PushEvent',
#   'actor': {'id': 76157401,
#    'login': 'qu14-9246-apvra',
#    'display_login': 'qu14-9246-apvra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qu14-9246-apvra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76157401?'},
#   'repo': {'id': 322251625,
#    'name': 'qu14-9246-apvra/Cus13rMq1a8a-aKiW2',
#    'url': 'https://api.github.com/repos/qu14-9246-apvra/Cus13rMq1a8a-aKiW2'},
#   'payload': {'push_id': 7617263616,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e9345203e76972dd3e3e4be7cf42670cd3a9e0a9',
#    'before': 'e0d593376474315c85a342a83242dbde4729b0c9',
#    'commits': [{'sha': 'e9345203e76972dd3e3e4be7cf42670cd3a9e0a9',
#      'author': {'email': '1gakuiPadak@gmail.com', 'name': 'qu14-9246-apvra'},
#      'message': 'xp,coin,count',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/qu14-9246-apvra/Cus13rMq1a8a-aKiW2/commits/e9345203e76972dd3e3e4be7cf42670cd3a9e0a9'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829484',
#   'type': 'PushEvent',
#   'actor': {'id': 6536985,
#    'login': 'ggdaltoso',
#    'display_login': 'ggdaltoso',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ggdaltoso',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6536985?'},
#   'repo': {'id': 206095591,
#    'name': 'Gympass/yoga',
#    'url': 'https://api.github.com/repos/Gympass/yoga'},
#   'payload': {'push_id': 7617263579,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/doc/create-a-doc-for-themes',
#    'head': '6e49abb886c3b09121f2f0bd7e24008859443ecb',
#    'before': '4e7640a2a80f107d6add3c9188c071e263500dcf',
#    'commits': [{'sha': '2f3bbe255f87b66b6b51983a56c1b3fbc81e6103',
#      'author': {'email': 'ggdaltoso@gmail.com', 'name': 'ggdaltoso'},
#      'message': 'chore(dps): handling window conflicts on react-inspector dependency\n\nit was needed to add this configuration because react-inspector makes use of window and it makes\nGatsby build to fail',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gympass/yoga/commits/2f3bbe255f87b66b6b51983a56c1b3fbc81e6103'},
#     {'sha': 'e4173f796088b29fbb0c38a4f8afaf062fd000f3',
#      'author': {'email': 'ggdaltoso@gmail.com', 'name': 'ggdaltoso'},
#      'message': 'docs(mdx): update column size and fix typos',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gympass/yoga/commits/e4173f796088b29fbb0c38a4f8afaf062fd000f3'},
#     {'sha': 'aa19735b85acdbd482384142886618ee7993ee49',
#      'author': {'email': 'ggdaltoso@gmail.com', 'name': 'ggdaltoso'},
#      'message': 'chore(tasks): add tasks for build',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gympass/yoga/commits/aa19735b85acdbd482384142886618ee7993ee49'},
#     {'sha': '6e49abb886c3b09121f2f0bd7e24008859443ecb',
#      'author': {'email': 'ggdaltoso@gmail.com', 'name': 'ggdaltoso'},
#      'message': 'chore(tasks): add test tasks',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gympass/yoga/commits/6e49abb886c3b09121f2f0bd7e24008859443ecb'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z',
#   'org': {'id': 26311162,
#    'login': 'Gympass',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Gympass',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26311162?'}},
#  {'id': '17354829489',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 533081,
#    'login': 'paulmillar',
#    'display_login': 'paulmillar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/paulmillar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/533081?'},
#   'repo': {'id': 9113580,
#    'name': 'dCache/dcache',
#    'url': 'https://api.github.com/repos/dCache/dcache'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/dCache/dcache/issues/5962',
#     'repository_url': 'https://api.github.com/repos/dCache/dcache',
#     'labels_url': 'https://api.github.com/repos/dCache/dcache/issues/5962/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/dCache/dcache/issues/5962/comments',
#     'events_url': 'https://api.github.com/repos/dCache/dcache/issues/5962/events',
#     'html_url': 'https://github.com/dCache/dcache/issues/5962',
#     'id': 947398264,
#     'node_id': 'MDU6SXNzdWU5NDczOTgyNjQ=',
#     'number': 5962,
#     'title': 'SRM TURL protocol depends on IPv4/IPv6',
#     'user': {'login': 'onnozweers',
#      'id': 781694,
#      'node_id': 'MDQ6VXNlcjc4MTY5NA==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/781694?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/onnozweers',
#      'html_url': 'https://github.com/onnozweers',
#      'followers_url': 'https://api.github.com/users/onnozweers/followers',
#      'following_url': 'https://api.github.com/users/onnozweers/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/onnozweers/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/onnozweers/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/onnozweers/subscriptions',
#      'organizations_url': 'https://api.github.com/users/onnozweers/orgs',
#      'repos_url': 'https://api.github.com/users/onnozweers/repos',
#      'events_url': 'https://api.github.com/users/onnozweers/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/onnozweers/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1699579138,
#       'node_id': 'MDU6TGFiZWwxNjk5NTc5MTM4',
#       'url': 'https://api.github.com/repos/dCache/dcache/labels/SRM',
#       'name': 'SRM',
#       'color': 'f9d0c4',
#       'default': False,
#       'description': 'Problems related to the SRM door/processing'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 13,
#     'created_at': '2021-07-19T08:20:23Z',
#     'updated_at': '2021-07-29T13:18:05Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': "Dear dCache devs,\r\n\r\nWe have this Atlas ticket: https://ggus.eu/index.php?mode=ticket_info&ticket_id=153027\r\n\r\nThey have found out that when using IPv4, they get a GSIFTP TURL from our SRM, and when using IPv6, they get a WebDAV TURL.\r\n\r\nAll our nodes are dual stack IPv4 and IPv6. We've recently set this values:\r\n\r\n```\r\nftp.loginbroker.address = ${host.name}.grid.surfsara.nl\r\nwebdav.loginbroker.address = ${host.name}.grid.surfsara.nl\r\nxrootd.loginbroker.address = ${host.name}.grid.surfsara.nl\r\n```\r\n\r\nFor tags, we have these generic settings:\r\n```\r\nxrootd.loginbroker.tags=srm\r\nwebdav.loginbroker.tags=cdmi,${dcache.loginbroker.tags}\r\n```\r\nThere are some very specific doors for which we have custom tags.\r\n\r\nAny idea why the choice of protocol may depend on IPv4/IPv6?\r\n\r\nKind regards,\r\nOnno",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/dCache/dcache/issues/comments/889136327',
#     'html_url': 'https://github.com/dCache/dcache/issues/5962#issuecomment-889136327',
#     'issue_url': 'https://api.github.com/repos/dCache/dcache/issues/5962',
#     'id': 889136327,
#     'node_id': 'IC_kwDOAIsP7M40_yTH',
#     'user': {'login': 'paulmillar',
#      'id': 533081,
#      'node_id': 'MDQ6VXNlcjUzMzA4MQ==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/533081?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/paulmillar',
#      'html_url': 'https://github.com/paulmillar',
#      'followers_url': 'https://api.github.com/users/paulmillar/followers',
#      'following_url': 'https://api.github.com/users/paulmillar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/paulmillar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/paulmillar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/paulmillar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/paulmillar/orgs',
#      'repos_url': 'https://api.github.com/users/paulmillar/repos',
#      'events_url': 'https://api.github.com/users/paulmillar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/paulmillar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-07-29T13:18:05Z',
#     'updated_at': '2021-07-29T13:18:05Z',
#     'author_association': 'MEMBER',
#     'body': "@onnozweers ,\r\nThanks for the help.  I think (hope?) we're narrowing down the possibilities.\r\n\r\nCould you check something else?\r\n\r\nCould you look at the access log file to see if dCache replies to srmPrepareToGet or srmPrepareToPut with a `status.code` value of `SRM_NOT_SUPPORTED` and an `status.explanation` value starting `Protocol(s) not supported:` ?",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z',
#   'org': {'id': 1384620,
#    'login': 'dCache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dCache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1384620?'}},
#  {'id': '17354829499',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 357362249,
#    'name': 'eric-kreis/eric-kreis',
#    'url': 'https://api.github.com/repos/eric-kreis/eric-kreis'},
#   'payload': {'push_id': 7617263606,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '7cb3a3f307fdb0392945aa09609da041622893fa',
#    'before': 'b0f8f5cecf836c1160d4bcf5dde2a6a93d9d516b',
#    'commits': [{'sha': '7cb3a3f307fdb0392945aa09609da041622893fa',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/eric-kreis/eric-kreis/commits/7cb3a3f307fdb0392945aa09609da041622893fa'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829481',
#   'type': 'ForkEvent',
#   'actor': {'id': 8744019,
#    'login': 'ezhangle',
#    'display_login': 'ezhangle',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ezhangle',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8744019?'},
#   'repo': {'id': 48671966,
#    'name': 'skywind3000/BasicBitmap',
#    'url': 'https://api.github.com/repos/skywind3000/BasicBitmap'},
#   'payload': {'forkee': {'id': 390730216,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkzOTA3MzAyMTY=',
#     'name': 'BasicBitmap',
#     'full_name': 'ezhangle/BasicBitmap',
#     'private': False,
#     'owner': {'login': 'ezhangle',
#      'id': 8744019,
#      'node_id': 'MDQ6VXNlcjg3NDQwMTk=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/8744019?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ezhangle',
#      'html_url': 'https://github.com/ezhangle',
#      'followers_url': 'https://api.github.com/users/ezhangle/followers',
#      'following_url': 'https://api.github.com/users/ezhangle/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ezhangle/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ezhangle/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ezhangle/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ezhangle/orgs',
#      'repos_url': 'https://api.github.com/users/ezhangle/repos',
#      'events_url': 'https://api.github.com/users/ezhangle/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ezhangle/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/ezhangle/BasicBitmap',
#     'description': 'Simple and high-performance and platform independent Bitmap class (34% faster than GDI/GDI+, 40% faster than DDraw)',
#     'fork': True,
#     'url': 'https://api.github.com/repos/ezhangle/BasicBitmap',
#     'forks_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/forks',
#     'keys_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/teams',
#     'hooks_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/hooks',
#     'issue_events_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/events',
#     'assignees_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/tags',
#     'blobs_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/languages',
#     'stargazers_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/stargazers',
#     'contributors_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/contributors',
#     'subscribers_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/subscribers',
#     'subscription_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/subscription',
#     'commits_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/merges',
#     'archive_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/downloads',
#     'issues_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/ezhangle/BasicBitmap/deployments',
#     'created_at': '2021-07-29T13:18:05Z',
#     'updated_at': '2021-06-14T13:26:25Z',
#     'pushed_at': '2021-02-16T16:59:03Z',
#     'git_url': 'git://github.com/ezhangle/BasicBitmap.git',
#     'ssh_url': 'git@github.com:ezhangle/BasicBitmap.git',
#     'clone_url': 'https://github.com/ezhangle/BasicBitmap.git',
#     'svn_url': 'https://github.com/ezhangle/BasicBitmap',
#     'homepage': '',
#     'size': 161,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'mit',
#      'name': 'MIT License',
#      'spdx_id': 'MIT',
#      'url': 'https://api.github.com/licenses/mit',
#      'node_id': 'MDc6TGljZW5zZTEz'},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829459',
#   'type': 'PushEvent',
#   'actor': {'id': 79338992,
#    'login': 'IVBACK',
#    'display_login': 'IVBACK',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IVBACK',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79338992?'},
#   'repo': {'id': 390156875,
#    'name': 'IVBACK/RestfulApiFront',
#    'url': 'https://api.github.com/repos/IVBACK/RestfulApiFront'},
#   'payload': {'push_id': 7617263583,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '563d8b97a317581b4b1fbb31aa04045e109f72e6',
#    'before': '1d4d8d3f888affc8ffdd19fa6140cb02f264b5db',
#    'commits': [{'sha': '563d8b97a317581b4b1fbb31aa04045e109f72e6',
#      'author': {'email': 'esatoglu@YMDEPO5-LP-82', 'name': 'esatoglu'},
#      'message': 'Bug Fixes And Progress Dialog Added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/IVBACK/RestfulApiFront/commits/563d8b97a317581b4b1fbb31aa04045e109f72e6'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829473',
#   'type': 'CreateEvent',
#   'actor': {'id': 9138515,
#    'login': 'jkotrc',
#    'display_login': 'jkotrc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jkotrc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9138515?'},
#   'repo': {'id': 279125428,
#    'name': 'jkotrc/Field-Plotter',
#    'url': 'https://api.github.com/repos/jkotrc/Field-Plotter'},
#   'payload': {'ref': 'master-indev',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A program that plots electric fields in 3D space',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829476',
#   'type': 'WatchEvent',
#   'actor': {'id': 79154405,
#    'login': 'idfix007',
#    'display_login': 'idfix007',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/idfix007',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79154405?'},
#   'repo': {'id': 128671856,
#    'name': 'rootm0s/WinPwnage',
#    'url': 'https://api.github.com/repos/rootm0s/WinPwnage'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829468',
#   'type': 'PushEvent',
#   'actor': {'id': 46037524,
#    'login': 'ZeTw',
#    'display_login': 'ZeTw',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ZeTw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46037524?'},
#   'repo': {'id': 390663703,
#    'name': 'ZeTw/deepLearning_Test',
#    'url': 'https://api.github.com/repos/ZeTw/deepLearning_Test'},
#   'payload': {'push_id': 7617263576,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fc4883ee28d75b9c3023859451bbcbdca5a56b9f',
#    'before': '6fe6471006adfd1e973bce3f31e611a7755fc62c',
#    'commits': [{'sha': 'fc4883ee28d75b9c3023859451bbcbdca5a56b9f',
#      'author': {'email': '46037524+ZeTw@users.noreply.github.com',
#       'name': 'ZeTw'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ZeTw/deepLearning_Test/commits/fc4883ee28d75b9c3023859451bbcbdca5a56b9f'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829472',
#   'type': 'PushEvent',
#   'actor': {'id': 541490,
#    'login': 'morrah',
#    'display_login': 'morrah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/morrah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/541490?'},
#   'repo': {'id': 224001345,
#    'name': 'morrah/oro-market',
#    'url': 'https://api.github.com/repos/morrah/oro-market'},
#   'payload': {'push_id': 7617263581,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0f6201d13b2616c1b0bb3415317009632e03ef90',
#    'before': '2facab482b8c565727a5c9ed7a3b1030ff2d2cdd',
#    'commits': [{'sha': '0f6201d13b2616c1b0bb3415317009632e03ef90',
#      'author': {'email': 'morrah@users.noreply.github.com', 'name': 'morrah'},
#      'message': 'data update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/morrah/oro-market/commits/0f6201d13b2616c1b0bb3415317009632e03ef90'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829444',
#   'type': 'PushEvent',
#   'actor': {'id': 80447279,
#    'login': 'ohju96',
#    'display_login': 'ohju96',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ohju96',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80447279?'},
#   'repo': {'id': 381882665,
#    'name': 'ohju96/SpringProject',
#    'url': 'https://api.github.com/repos/ohju96/SpringProject'},
#   'payload': {'push_id': 7617263570,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cb5d0bccd13e20970c249ccf9da62a13853bbd4a',
#    'before': '4acb5ff4787b8a30b27904a88ca3490ba81cbdde',
#    'commits': [{'sha': 'cb5d0bccd13e20970c249ccf9da62a13853bbd4a',
#      'author': {'email': 'ohju96@naver.com', 'name': 'ohju96'},
#      'message': 'Main 컨트롤러 -> User 컨트롤러로 변경',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ohju96/SpringProject/commits/cb5d0bccd13e20970c249ccf9da62a13853bbd4a'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829458',
#   'type': 'CreateEvent',
#   'actor': {'id': 44091822,
#    'login': 'kushthedude',
#    'display_login': 'kushthedude',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kushthedude',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44091822?'},
#   'repo': {'id': 386360198,
#    'name': 'kushthedude/blobber',
#    'url': 'https://api.github.com/repos/kushthedude/blobber'},
#   'payload': {'ref': 'fix_go_sum',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A storage provider (blobber) interface to the blockchain and consumers of storage.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829437',
#   'type': 'PushEvent',
#   'actor': {'id': 41495451,
#    'login': 'yangbiny',
#    'display_login': 'yangbiny',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yangbiny',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41495451?'},
#   'repo': {'id': 356215864,
#    'name': 'yangbiny/imp',
#    'url': 'https://api.github.com/repos/yangbiny/imp'},
#   'payload': {'push_id': 7617263573,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'aa989849c9d9b4d88ef12e847cd1fff0a723ed32',
#    'before': '18647285cfc900f72c237a5bac13c5003ea54028',
#    'commits': [{'sha': 'aa989849c9d9b4d88ef12e847cd1fff0a723ed32',
#      'author': {'email': 'impassive@aliyun.com', 'name': 'Impassive'},
#      'message': 'fix response',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/yangbiny/imp/commits/aa989849c9d9b4d88ef12e847cd1fff0a723ed32'}]},
#   'public': True,
#   'created_at': '2021-07-29T13:18:05Z'},
#  {'id': '17354829449',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 372793083,
#    'name': 'conda-forge/posthog-feedstock',
#    'url': 'https://api.github.com/repos/conda-forge/posthog-feedstock'},
# ...
#     'statuses_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/statuses/1f750b877339a0f768d9fc0b6cc0f60c9f2777bb',
#     'head': {'label': 'davidhorstmann-arm:migrate-sphinx',
#      'ref': 'migrate-sphinx',
#      'sha': '1f750b877339a0f768d9fc0b6cc0f60c9f2777bb',
#      'user': {'login': 'davidhorstmann-arm',
#       'id': 70948878,
#       'node_id': 'MDQ6VXNlcjcwOTQ4ODc4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/70948878?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/davidhorstmann-arm',
#       'html_url': 'https://github.com/davidhorstmann-arm',
#       'followers_url': 'https://api.github.com/users/davidhorstmann-arm/followers',
#       'following_url': 'https://api.github.com/users/davidhorstmann-arm/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/davidhorstmann-arm/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/davidhorstmann-arm/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/davidhorstmann-arm/subscriptions',
#       'organizations_url': 'https://api.github.com/users/davidhorstmann-arm/orgs',
#       'repos_url': 'https://api.github.com/users/davidhorstmann-arm/repos',
#       'events_url': 'https://api.github.com/users/davidhorstmann-arm/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/davidhorstmann-arm/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 375644782,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzU2NDQ3ODI=',
#       'name': 'mbedtls-docs',
#       'full_name': 'davidhorstmann-arm/mbedtls-docs',
#       'private': False,
#       'owner': {'login': 'davidhorstmann-arm',
#        'id': 70948878,
#        'node_id': 'MDQ6VXNlcjcwOTQ4ODc4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/70948878?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/davidhorstmann-arm',
#        'html_url': 'https://github.com/davidhorstmann-arm',
#        'followers_url': 'https://api.github.com/users/davidhorstmann-arm/followers',
#        'following_url': 'https://api.github.com/users/davidhorstmann-arm/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/davidhorstmann-arm/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/davidhorstmann-arm/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/davidhorstmann-arm/subscriptions',
#        'organizations_url': 'https://api.github.com/users/davidhorstmann-arm/orgs',
#        'repos_url': 'https://api.github.com/users/davidhorstmann-arm/repos',
#        'events_url': 'https://api.github.com/users/davidhorstmann-arm/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/davidhorstmann-arm/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/davidhorstmann-arm/mbedtls-docs',
#       'description': 'Version-independent documentation for Mbed TLS',
#       'fork': True,
#       'url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs',
#       'forks_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/forks',
#       'keys_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/teams',
#       'hooks_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/hooks',
#       'issue_events_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/events',
#       'assignees_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/tags',
#       'blobs_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/languages',
#       'stargazers_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/stargazers',
#       'contributors_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/contributors',
#       'subscribers_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/subscribers',
#       'subscription_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/subscription',
#       'commits_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/merges',
#       'archive_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/downloads',
#       'issues_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/davidhorstmann-arm/mbedtls-docs/deployments',
#       'created_at': '2021-06-10T09:35:54Z',
#       'updated_at': '2021-07-21T14:18:27Z',
#       'pushed_at': '2021-07-29T09:45:19Z',
#       'git_url': 'git://github.com/davidhorstmann-arm/mbedtls-docs.git',
#       'ssh_url': 'git@github.com:davidhorstmann-arm/mbedtls-docs.git',
#       'clone_url': 'https://github.com/davidhorstmann-arm/mbedtls-docs.git',
#       'svn_url': 'https://github.com/davidhorstmann-arm/mbedtls-docs',
#       'homepage': None,
#       'size': 852,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'ARMmbed:main',
#      'ref': 'main',
#      'sha': 'e842633467dc57cf99930437a80393d62b251057',
#      'user': {'login': 'ARMmbed',
#       'id': 8916057,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MTYwNTc=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8916057?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ARMmbed',
#       'html_url': 'https://github.com/ARMmbed',
#       'followers_url': 'https://api.github.com/users/ARMmbed/followers',
#       'following_url': 'https://api.github.com/users/ARMmbed/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ARMmbed/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ARMmbed/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ARMmbed/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ARMmbed/orgs',
#       'repos_url': 'https://api.github.com/users/ARMmbed/repos',
#       'events_url': 'https://api.github.com/users/ARMmbed/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ARMmbed/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 311403453,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMTE0MDM0NTM=',
#       'name': 'mbedtls-docs',
#       'full_name': 'ARMmbed/mbedtls-docs',
#       'private': False,
#       'owner': {'login': 'ARMmbed',
#        'id': 8916057,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5MTYwNTc=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/8916057?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ARMmbed',
#        'html_url': 'https://github.com/ARMmbed',
#        'followers_url': 'https://api.github.com/users/ARMmbed/followers',
#        'following_url': 'https://api.github.com/users/ARMmbed/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ARMmbed/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ARMmbed/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ARMmbed/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ARMmbed/orgs',
#        'repos_url': 'https://api.github.com/users/ARMmbed/repos',
#        'events_url': 'https://api.github.com/users/ARMmbed/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ARMmbed/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/ARMmbed/mbedtls-docs',
#       'description': 'Version-independent documentation for Mbed TLS',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs',
#       'forks_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/forks',
#       'keys_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/teams',
#       'hooks_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/events',
#       'assignees_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/tags',
#       'blobs_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/languages',
#       'stargazers_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/subscription',
#       'commits_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/merges',
#       'archive_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/downloads',
#       'issues_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/deployments',
#       'created_at': '2020-11-09T16:46:43Z',
#       'updated_at': '2021-07-15T08:26:12Z',
#       'pushed_at': '2021-07-29T09:45:20Z',
#       'git_url': 'git://github.com/ARMmbed/mbedtls-docs.git',
#       'ssh_url': 'git@github.com:ARMmbed/mbedtls-docs.git',
#       'clone_url': 'https://github.com/ARMmbed/mbedtls-docs.git',
#       'svn_url': 'https://github.com/ARMmbed/mbedtls-docs',
#       'homepage': None,
#       'size': 847,
#       'stargazers_count': 1,
#       'watchers_count': 1,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 4,
#       'open_issues': 3,
#       'watchers': 1,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/pulls/16'},
#      'html': {'href': 'https://github.com/ARMmbed/mbedtls-docs/pull/16'},
#      'issue': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/issues/16'},
#      'comments': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/issues/16/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/pulls/16/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/pulls/16/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ARMmbed/mbedtls-docs/statuses/1f750b877339a0f768d9fc0b6cc0f60c9f2777bb'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-07-29T13:15:43Z',
#   'org': {'id': 8916057,
#    'login': 'ARMmbed',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ARMmbed',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8916057?'}}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-6102ac20-59c480f16e3ca1147a19fceb'},
#  'origin': '106.1.232.15',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-6102ac22-0213a3e8183289e575bf42b2'},
#  'json': None,
#  'origin': '106.1.232.15',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.22.0',
#   'X-Amzn-Trace-Id': 'Root=1-6102ac2e-4f44c15722f55f246b559a5d'},
#  'json': None,
#  'origin': '106.1.232.15',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
